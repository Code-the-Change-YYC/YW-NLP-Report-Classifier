# %% [markdown]
# Simple single dense layer architecture of neutral network
# import dependencies

# %%
import os
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential


from tensorflow.keras.layers import Embedding,Dense
from tensorflow.keras.layers import SpatialDropout1D,Conv1D,GlobalMaxPooling1D
from tensorflow.keras.layers import Flatten,Dropout

from tensorflow.keras.callbacks import ModelCheckpoint


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import nltk,re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve

# %% [markdown]
# Basic text prepocessing function

# %%
def preprocessing_txt(list_of_sents:pd)->list:
    
    df_sents = list_of_sents
    lemmatizer = nltk.WordNetLemmatizer()
    stop_words = set(stopwords.words("english"))
    new_list_sents = []
    for sents in df_sents:   
        tokens = word_tokenize(sents)
        words = " ".join([lemmatizer.lemmatize(word.lower()) for word in tokens if word.isalpha() or word not in stop_words]) 
        new_list_sents.append(words)

    return new_list_sents

# %% [markdown]
# read file and constructed feature engineered data X and proper encoded labels y

# %%
replace_initial = "someone"
df= pd.read_csv("data-processed.csv")
X_raw = df["DESCRIPTION"]
X_rnm = pd.array([re.sub(r"\{\{[^\{\}]+\}\}\w?", replace_initial, str1) for str1 in X_raw])
X_ = preprocessing_txt(X_rnm)
Y_ = np.array([1 if t == 'Medical emergency' else 0 for t in df["INCIDENT_TYPE_1"]])

# %% [markdown]
# Here we use sklearn split function to seperate train and test data at 80% and 20%

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_,Y_,train_size = 0.80, random_state = 1, shuffle = True)
X_test
# Out:
# ['not long after 1pm the fire alarm went off at providence . i doubled checked the kitchen to confirm the oven wa off and it wa . something in my gut told me to check unit 201 . the resident that life there left very quickly 2 minute earlier and had left in such a manner i noticed and remembered . a soon a i got to the 2nd floor i smelt smoke . i used my foot to open the door and a huge cloud of smoke came out . i immediately called 911 and alerted the other resident to get out of the building',
#  'someone entered the hallway and someone began yelling at her and getting in her face , staff intervened and asked the woman to separate , someone entered the office someone followed her and threatened to beat her up right in the office , someone remained silent . someone began yelling at writer and refused to leave the office , someone yelled in writer face until she left the office . someone then brought 3 guest into the building despite knowing she is not allowed guest , someone wa called and someone and guest were removed .',
#  "transitional someone staff someone wa informed that housekeeping staff someone wa poked with a needle while picking up garbage . there were approximately 7 needle exposed in the garbage bag which wa identified a belonging to resident someone372 . someone went to someone hospital immediately after and brought a sharp container with the used needle . someone someone spoke with someone372 and the client disclosed that she 's been diagnosed with someone c and that she did throw away the used needle in her garbage .",
#  'someone came to staff stating that she had abdominal pain that wa really bad . someone wa groaning in pain . writer called someone paramedic and explained someone symptom . they stated that with pain in the abdominal it could be anything and someone would be better . they connected writer with someone and they came quickly after and transported someone to hospital .',
#  'writer responded to call from someone over safety issue by someone 355. someone called police which arrived at 2:20 am . writer meet police while someone down . someone had a lengthy dissuasion and police later asked writer to let them on the floor to listen if anything wa going on in someone 355 . writer declined and informed police that this is a breach privacy and can not allow them on the floor . writer contact on call but phone went on voicemail . police refused to give their contact alleging protocol & privacy .',
#  'someone asked staff to call 911 ; she felt unsafe at shelter ( staff letting men in building , woman getting someone to beat her up , someone putting meth in her clothes ) . staff told her that there wa no emergency ; she took it upon herself to call 911. police were sent . police arrived around 1:30 am ; stated that they would not take someone anywhere because they considered someone to be a very safe place . someone wa not happy with this and called 911 again . someone wa on her way out to take her own taxi .',
#  'writer wa alerted by an unknown male that someone wa highly intoxicated in the alleyway someone of the building . when writer went to the alleyway someone wa sitting on the ground and unable to communicate with writer . writer asked the male if he knew someone and he said yes , she wa his friend and had called him , but he wasnt going to take her with the state she wa in . he then got in his vehicle and drove away . writer assessed client and she wa injured on her left shoulder and bleeding from head . someone called .',
#  "writer completed regular hourly safety check on client in response to client 's substance use presentation yesterday . writer observed client 's presentation to be same , breathing regularly , and not verbally responding to writer 's prompt or question . writer observed dried blood on client 's face and mouth . after consultation regarding prolonged presentation after substance use , writer called someone paramedic and wa transferred to someone . someone arrived , assessed , and transported client to hospital .",
#  'someone came into the someone requesting for someone . staff asked what she want to use someone for . someone said that she want to use someone for headache . writer asked if she is having other symptom . someone said that she ha been feeling fever since when she came back from drop in centre ( someone ) yesterday . writer did not give her someone because we do not administer medication . writer called someone at 8.50pm to attend to someone . someone staff came into the someone and left with someone at 9.55pm .',
#  'at 07.00 overnight staff passed on that someone had been loud and using threatening language since 3 am . attempt to deescalate were unsuccessful . on call wa contacted but no answer . shelter supervisor wa someone a client wa threatening staff . someone were called and someone . someone gathered her belonging and left with someone at 09.10 .']

# %% [markdown]
# Here we use tensorflow tokenizer. The unique function we explore here is the oov_token which represent unknown words, in our cases it should provide some better representation since we will be using embedding word vector.

# %%
tokenizer = Tokenizer(num_words=None,
                    lower =True,oov_token="<oov>")
tokenizer.fit_on_texts(X_train)
unique_words = len(tokenizer.word_index)+1

# %% [markdown]
# Here we further prepare our text tokens be ready for embedding layers by two techniques:
# 1. texts to sequences: It encodes word tokens into digits as you can see in word_index below
# 2. padded text: it is basic fill up the space to match to all same length. here I did not restrict my max words in padding to capture all word count.

# %%
train_sequences = tokenizer.texts_to_sequences(X_train)
padded_train = pad_sequences(train_sequences,padding = "post")

test_sequences = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(test_sequences,padding = "post")
max_len = len(padded_test[0])
tokenizer.word_index
# Out:
# {'<oov>': 1,
#  'someone': 2,
#  'and': 3,
#  'to': 4,
#  'the': 5,
#  'wa': 6,
#  'staff': 7,
#  'her': 8,
#  'a': 9,
#  'she': 10,
#  'at': 11,
#  'that': 12,
#  'writer': 13,
#  'in': 14,
#  'called': 15,
#  'with': 16,
#  'on': 17,
#  'of': 18,
#  'arrived': 19,
#  'client': 20,
#  'hospital': 21,
#  'for': 22,
#  'came': 23,
#  'not': 24,
#  'had': 25,
#  'they': 26,
#  "'s": 27,
#  'went': 28,
#  'police': 29,
#  'from': 30,
#  'call': 31,
#  'asked': 32,
#  'took': 33,
#  '911': 34,
#  'up': 35,
#  'this': 36,
#  'unit': 37,
#  'building': 38,
#  'room': 39,
#  'but': 40,
#  'office': 41,
#  'guest': 42,
#  'go': 43,
#  'left': 44,
#  'pain': 45,
#  'did': 46,
#  'is': 47,
#  'back': 48,
#  'stated': 49,
#  'when': 50,
#  'were': 51,
#  'he': 52,
#  'check': 53,
#  'out': 54,
#  'an': 55,
#  'floor': 56,
#  'would': 57,
#  'down': 58,
#  'by': 59,
#  'told': 60,
#  'assessed': 61,
#  'be': 62,
#  'after': 63,
#  'if': 64,
#  'around': 65,
#  'taken': 66,
#  'am': 67,
#  'informed': 68,
#  'leave': 69,
#  'safety': 70,
#  'found': 71,
#  '10': 72,
#  'into': 73,
#  'then': 74,
#  'said': 75,
#  'could': 76,
#  'get': 77,
#  'having': 78,
#  '9': 79,
#  'breathing': 80,
#  'resident': 81,
#  'yelling': 82,
#  'them': 83,
#  'about': 84,
#  'time': 85,
#  'while': 86,
#  'i': 87,
#  'door': 88,
#  'phone': 89,
#  '12': 90,
#  'ha': 91,
#  'non': 92,
#  '5': 93,
#  'minute': 94,
#  'it': 95,
#  '1': 96,
#  'refused': 97,
#  'paramedic': 98,
#  'take': 99,
#  '3': 100,
#  '30': 101,
#  'emergency': 102,
#  'who': 103,
#  'assessment': 104,
#  "''": 105,
#  '8': 106,
#  'him': 107,
#  'property': 108,
#  'no': 109,
#  '11': 110,
#  'have': 111,
#  'off': 112,
#  'reported': 113,
#  'heard': 114,
#  'chest': 115,
#  '2': 116,
#  'approximately': 117,
#  'will': 118,
#  'there': 119,
#  'checked': 120,
#  '4': 121,
#  'became': 122,
#  'seizure': 123,
#  'his': 124,
#  'made': 125,
#  'talk': 126,
#  'aggressive': 127,
#  'ambulance': 128,
#  'due': 129,
#  'child': 130,
#  'blood': 131,
#  'report': 132,
#  'some': 133,
#  'spoke': 134,
#  'provided': 135,
#  'which': 136,
#  'so': 137,
#  'expressed': 138,
#  'or': 139,
#  'decided': 140,
#  'observed': 141,
#  'going': 142,
#  'well': 143,
#  "n't": 144,
#  'continued': 145,
#  'feeling': 146,
#  'needed': 147,
#  'plan': 148,
#  'worker': 149,
#  'pill': 150,
#  'other': 151,
#  'towards': 152,
#  'requested': 153,
#  'entered': 154,
#  'come': 155,
#  'tried': 156,
#  'later': 157,
#  '6': 158,
#  'herself': 159,
#  'started': 160,
#  'all': 161,
#  'declined': 162,
#  'saw': 163,
#  'being': 164,
#  'taking': 165,
#  'need': 166,
#  'been': 167,
#  'attended': 168,
#  '7': 169,
#  'face': 170,
#  'wanted': 171,
#  'got': 172,
#  'stating': 173,
#  'situation': 174,
#  'another': 175,
#  'breath': 176,
#  'few': 177,
#  'outside': 178,
#  'unknown': 179,
#  'immediately': 180,
#  'supervisor': 181,
#  'screaming': 182,
#  'saying': 183,
#  'do': 184,
#  'one': 185,
#  'received': 186,
#  'symptom': 187,
#  'able': 188,
#  'gave': 189,
#  'we': 190,
#  'their': 191,
#  'concern': 192,
#  'pm': 193,
#  'officer': 194,
#  'very': 195,
#  'also': 196,
#  'number': 197,
#  'began': 198,
#  'agreed': 199,
#  'however': 200,
#  'sheldon': 201,
#  'more': 202,
#  'because': 203,
#  'further': 204,
#  'removed': 205,
#  'partner': 206,
#  '15': 207,
#  'over': 208,
#  'camera': 209,
#  'administered': 210,
#  'until': 211,
#  'coming': 212,
#  'fire': 213,
#  'met': 214,
#  'rockyview': 215,
#  'transported': 216,
#  'incident': 217,
#  'bed': 218,
#  '20': 219,
#  'let': 220,
#  'walk': 221,
#  'before': 222,
#  'someonet': 223,
#  'see': 224,
#  'suicidal': 225,
#  'escalated': 226,
#  'area': 227,
#  'noticed': 228,
#  'what': 229,
#  'responded': 230,
#  'hour': 231,
#  'unable': 232,
#  'night': 233,
#  'responsive': 234,
#  'taxi': 235,
#  'calling': 236,
#  '00': 237,
#  'side': 238,
#  'support': 239,
#  'make': 240,
#  'attempted': 241,
#  'lot': 242,
#  'showed': 243,
#  'fell': 244,
#  'returned': 245,
#  'health': 246,
#  'brought': 247,
#  'contacted': 248,
#  '00pm': 249,
#  'through': 250,
#  'assistance': 251,
#  'request': 252,
#  'respond': 253,
#  'can': 254,
#  'chair': 255,
#  'how': 256,
#  'indicated': 257,
#  'advised': 258,
#  'ass': 259,
#  'elevator': 260,
#  'verbally': 261,
#  'man': 262,
#  'unconscious': 263,
#  'keep': 264,
#  'statement': 265,
#  'two': 266,
#  'unresponsive': 267,
#  'right': 268,
#  'medical': 269,
#  'experiencing': 270,
#  'escorted': 271,
#  'phoned': 272,
#  'during': 273,
#  '30pm': 274,
#  'here': 275,
#  '15pm': 276,
#  'responding': 277,
#  'belonging': 278,
#  'way': 279,
#  'front': 280,
#  'head': 281,
#  'suicide': 282,
#  'daughter': 283,
#  'laying': 284,
#  'window': 285,
#  'site': 286,
#  'member': 287,
#  'nose': 288,
#  'mom': 289,
#  'away': 290,
#  'disclosed': 291,
#  'want': 292,
#  'are': 293,
#  'own': 294,
#  'chumir': 295,
#  'day': 296,
#  'evening': 297,
#  '40pm': 298,
#  'eye': 299,
#  'last': 300,
#  'followed': 301,
#  'answer': 302,
#  'several': 303,
#  'file': 304,
#  'inside': 305,
#  'any': 306,
#  'desk': 307,
#  'intoxicated': 308,
#  'thought': 309,
#  'shortly': 310,
#  'presented': 311,
#  'information': 312,
#  'hand': 313,
#  'consulted': 314,
#  'consciousness': 315,
#  'm': 316,
#  'walked': 317,
#  'case': 318,
#  'completed': 319,
#  'used': 320,
#  'again': 321,
#  'second': 322,
#  'hallway': 323,
#  'complained': 324,
#  'stomach': 325,
#  'doe': 326,
#  'family': 327,
#  'hear': 328,
#  '45pm': 329,
#  'name': 330,
#  'alcohol': 331,
#  'appeared': 332,
#  'vitals': 333,
#  '30am': 334,
#  'knife': 335,
#  'once': 336,
#  'break': 337,
#  'given': 338,
#  'car': 339,
#  'someone15': 340,
#  'safe': 341,
#  'self': 342,
#  'bring': 343,
#  'physical': 344,
#  'talking': 345,
#  'contact': 346,
#  'still': 347,
#  'communicated': 348,
#  '5th': 349,
#  'know': 350,
#  '811': 351,
#  'where': 352,
#  'help': 353,
#  'sign': 354,
#  'speak': 355,
#  'question': 356,
#  'helped': 357,
#  '19': 358,
#  'group': 359,
#  '417': 360,
#  'medication': 361,
#  'main': 362,
#  'lobby': 363,
#  'person': 364,
#  'doing': 365,
#  'ground': 366,
#  'explained': 367,
#  'loud': 368,
#  'operator': 369,
#  'empty': 370,
#  'foothill': 371,
#  'talked': 372,
#  'rocky': 373,
#  'view': 374,
#  'me': 375,
#  'yelled': 376,
#  'ran': 377,
#  'vomiting': 378,
#  'like': 379,
#  'temperature': 380,
#  'entering': 381,
#  'holding': 382,
#  'bike': 383,
#  'seen': 384,
#  'felt': 385,
#  'knocked': 386,
#  'location': 387,
#  'sure': 388,
#  'hurt': 389,
#  'trying': 390,
#  'supported': 391,
#  'first': 392,
#  'home': 393,
#  'security': 394,
#  'son': 395,
#  'assisted': 396,
#  'grabbed': 397,
#  'arm': 398,
#  'upon': 399,
#  'harm': 400,
#  'feel': 401,
#  'someoneid': 402,
#  'u': 403,
#  'overdose': 404,
#  'downstairs': 405,
#  'threat': 406,
#  'kill': 407,
#  'banned': 408,
#  '4th': 409,
#  'risk': 410,
#  'you': 411,
#  'footage': 412,
#  'why': 413,
#  'noise': 414,
#  '201': 415,
#  'find': 416,
#  'amount': 417,
#  'body': 418,
#  'transport': 419,
#  'offered': 420,
#  'service': 421,
#  'doctor': 422,
#  '2019': 423,
#  'follow': 424,
#  'pack': 425,
#  'alerted': 426,
#  'both': 427,
#  'wall': 428,
#  'morning': 429,
#  'complete': 430,
#  'threatened': 431,
#  'emotional': 432,
#  'open': 433,
#  'leaving': 434,
#  'welcome': 435,
#  'waiting': 436,
#  'bldg': 437,
#  'alarm': 438,
#  'opened': 439,
#  'smoke': 440,
#  'hit': 441,
#  'use': 442,
#  'test': 443,
#  'sat': 444,
#  'glass': 445,
#  'link': 446,
#  'upstairs': 447,
#  'arrive': 448,
#  'looked': 449,
#  'involved': 450,
#  'thing': 451,
#  'team': 452,
#  '2020': 453,
#  'mother': 454,
#  'high': 455,
#  'pressure': 456,
#  'address': 457,
#  'stay': 458,
#  'community': 459,
#  'inform': 460,
#  'regarding': 461,
#  '45am': 462,
#  'via': 463,
#  '10pm': 464,
#  '20am': 465,
#  'cell': 466,
#  'earlier': 467,
#  'friend': 468,
#  '10am': 469,
#  'bleeding': 470,
#  'female': 471,
#  'shortness': 472,
#  'today': 473,
#  'bathroom': 474,
#  '04': 475,
#  '50': 476,
#  'naloxone': 477,
#  'sitting': 478,
#  'attend': 479,
#  'aggressively': 480,
#  'directed': 481,
#  'cry': 482,
#  'yesterday': 483,
#  'getting': 484,
#  'response': 485,
#  'four': 486,
#  'ex': 487,
#  'shift': 488,
#  'trouble': 489,
#  'put': 490,
#  "someone'someone": 491,
#  'difficulty': 492,
#  'attempt': 493,
#  'across': 494,
#  'street': 495,
#  'vehicle': 496,
#  'throwing': 497,
#  'using': 498,
#  'pushed': 499,
#  'ideation': 500,
#  'threw': 501,
#  'calm': 502,
#  'mental': 503,
#  'aid': 504,
#  'welfare': 505,
#  'placed': 506,
#  'care': 507,
#  'shared': 508,
#  'currently': 509,
#  'stair': 510,
#  'instructed': 511,
#  'escalate': 512,
#  'line': 513,
#  'stop': 514,
#  '55': 515,
#  'threatening': 516,
#  'approached': 517,
#  'lying': 518,
#  'wait': 519,
#  'continue': 520,
#  'baby': 521,
#  'bag': 522,
#  'appointment': 523,
#  'isolation': 524,
#  'event': 525,
#  'complaining': 526,
#  'reception': 527,
#  'should': 528,
#  'shelter': 529,
#  'co': 530,
#  '25': 531,
#  'only': 532,
#  'heart': 533,
#  'agitated': 534,
#  'behavior': 535,
#  'look': 536,
#  'overdosed': 537,
#  '15am': 538,
#  'same': 539,
#  'instruction': 540,
#  'many': 541,
#  'good': 542,
#  'attention': 543,
#  'position': 544,
#  'closed': 545,
#  'slammed': 546,
#  'boyfriend': 547,
#  'wrong': 548,
#  '50am': 549,
#  'residence': 550,
#  'different': 551,
#  '50pm': 552,
#  'apartment': 553,
#  'speaking': 554,
#  'min': 555,
#  'reminded': 556,
#  'road': 557,
#  'under': 558,
#  'laid': 559,
#  'warrant': 560,
#  'confirmed': 561,
#  'kid': 562,
#  'voice': 563,
#  'witnessed': 564,
#  'say': 565,
#  'between': 566,
#  'form': 567,
#  '45': 568,
#  'ok': 569,
#  'email': 570,
#  '23': 571,
#  'clinical': 572,
#  'telephoned': 573,
#  'place': 574,
#  'third': 575,
#  'cough': 576,
#  'undisclosed': 577,
#  'someone\x92s': 578,
#  'kitchen': 579,
#  'point': 580,
#  'program': 581,
#  'witness': 582,
#  'barred': 583,
#  'complaint': 584,
#  'okay': 585,
#  'badge': 586,
#  'hard': 587,
#  'investigate': 588,
#  'deep': 589,
#  'w': 590,
#  'month': 591,
#  'onto': 592,
#  'condition': 593,
#  'normal': 594,
#  'male': 595,
#  'asleep': 596,
#  'give': 597,
#  'shot': 598,
#  'cut': 599,
#  'stopped': 600,
#  'parent': 601,
#  'people': 602,
#  'added': 603,
#  'woke': 604,
#  '205': 605,
#  'highly': 606,
#  'than': 607,
#  'blue': 608,
#  'meth': 609,
#  'space': 610,
#  'bottle': 611,
#  'de': 612,
#  'scene': 613,
#  'confirm': 614,
#  '303': 615,
#  'low': 616,
#  'discussed': 617,
#  'every': 618,
#  'notified': 619,
#  'object': 620,
#  'providence': 621,
#  'verbal': 622,
#  'someonep': 623,
#  'walking': 624,
#  'detail': 625,
#  'pick': 626,
#  'bleed': 627,
#  'others': 628,
#  'delusion': 629,
#  'smoking': 630,
#  'encouraged': 631,
#  'rest': 632,
#  'emerg': 633,
#  'policy': 634,
#  'performed': 635,
#  'moved': 636,
#  'next': 637,
#  'better': 638,
#  'finding': 639,
#  'above': 640,
#  'bad': 641,
#  'state': 642,
#  'stand': 643,
#  'hosp': 644,
#  'severe': 645,
#  'past': 646,
#  'three': 647,
#  'informing': 648,
#  'fentanyl': 649,
#  'dispatcher': 650,
#  'revived': 651,
#  'arrested': 652,
#  'gravol': 653,
#  'catch': 654,
#  'struggling': 655,
#  'anxiety': 656,
#  'looking': 657,
#  'kicked': 658,
#  'really': 659,
#  'fever': 660,
#  'emerge': 661,
#  'tell': 662,
#  'chumer': 663,
#  'work': 664,
#  'along': 665,
#  'tomorrow': 666,
#  'arriving': 667,
#  '2nd': 668,
#  'together': 669,
#  'falling': 670,
#  'fall': 671,
#  '1pm': 672,
#  'stove': 673,
#  '21': 674,
#  'postured': 675,
#  'charge': 676,
#  'die': 677,
#  'garbage': 678,
#  'separated': 679,
#  'pocket': 680,
#  'broken': 681,
#  'rushed': 682,
#  'meet': 683,
#  'wound': 684,
#  'cst': 685,
#  'worried': 686,
#  'return': 687,
#  'client\x92s': 688,
#  '40am': 689,
#  'banging': 690,
#  '7am': 691,
#  'panic': 692,
#  '40': 693,
#  'concluded': 694,
#  'sent': 695,
#  'ice': 696,
#  'examined': 697,
#  'bloody': 698,
#  'altercation': 699,
#  'quickly': 700,
#  'conscious': 701,
#  'recently': 702,
#  'stayed': 703,
#  'suggested': 704,
#  'just': 705,
#  'kept': 706,
#  'd': 707,
#  'transitional': 708,
#  'included': 709,
#  'reviewing': 710,
#  'enter': 711,
#  'tonight': 712,
#  'upset': 713,
#  'roughly': 714,
#  '12am': 715,
#  'my': 716,
#  'happened': 717,
#  'shallow': 718,
#  'giving': 719,
#  'attack': 720,
#  'short': 721,
#  'since': 722,
#  'everything': 723,
#  'old': 724,
#  '20pm': 725,
#  'assist': 726,
#  'sound': 727,
#  '405': 728,
#  'expressing': 729,
#  'anything': 730,
#  'isolating': 731,
#  'checklist': 732,
#  '55am': 733,
#  'wellness': 734,
#  'intake': 735,
#  'determined': 736,
#  'speech': 737,
#  'direction': 738,
#  'behind': 739,
#  'happening': 740,
#  'problem': 741,
#  'sweating': 742,
#  'premise': 743,
#  'hospitalized': 744,
#  '05': 745,
#  'assessing': 746,
#  'package': 747,
#  'lip': 748,
#  'screamed': 749,
#  'intervene': 750,
#  'ended': 751,
#  'wake': 752,
#  'cold': 753,
#  '35pm': 754,
#  'ask': 755,
#  'believed': 756,
#  'please': 757,
#  'coordinator': 758,
#  'concerned': 759,
#  'session': 760,
#  'week': 761,
#  'regulate': 762,
#  'text': 763,
#  'triggered': 764,
#  'detector': 765,
#  'result': 766,
#  'alone': 767,
#  'neighbor': 768,
#  'b': 769,
#  'claiming': 770,
#  'noon': 771,
#  'sharp': 772,
#  'groaning': 773,
#  'advil': 774,
#  'arrival': 775,
#  'item': 776,
#  'afternoon': 777,
#  'washroom': 778,
#  'part': 779,
#  'remove': 780,
#  'woman': 781,
#  'facilitator': 782,
#  'k': 783,
#  'age': 784,
#  'moment': 785,
#  'accepted': 786,
#  'asking': 787,
#  'ca': 788,
#  'too': 789,
#  'replied': 790,
#  'commit': 791,
#  'awake': 792,
#  'medic': 793,
#  '305': 794,
#  'intent': 795,
#  'aggression': 796,
#  'entrance': 797,
#  'exchange': 798,
#  'overdosing': 799,
#  'someone19': 800,
#  'inquired': 801,
#  'pulled': 802,
#  'mace': 803,
#  'arrest': 804,
#  'someone44': 805,
#  'hub': 806,
#  '406': 807,
#  'large': 808,
#  'movement': 809,
#  '24': 810,
#  'gone': 811,
#  '6am': 812,
#  'proceeded': 813,
#  'pronounced': 814,
#  'deceased': 815,
#  'strip': 816,
#  'twitching': 817,
#  'barely': 818,
#  'half': 819,
#  'grovel': 820,
#  'even': 821,
#  'though': 822,
#  'start': 823,
#  'attending': 824,
#  'recovery': 825,
#  '513': 826,
#  'successfully': 827,
#  'prior': 828,
#  'mid': 829,
#  'knock': 830,
#  'announced': 831,
#  'shivering': 832,
#  'flickering': 833,
#  'making': 834,
#  'breathe': 835,
#  'reviewed': 836,
#  'ago': 837,
#  'our': 838,
#  'swollen': 839,
#  '35am': 840,
#  'served': 841,
#  'meeting': 842,
#  'regard': 843,
#  'gather': 844,
#  '209': 845,
#  'known': 846,
#  'substance': 847,
#  'sit': 848,
#  'notice': 849,
#  'himself': 850,
#  'manner': 851,
#  'prompted': 852,
#  'piece': 853,
#  'within': 854,
#  'finished': 855,
#  'water': 856,
#  'standing': 857,
#  'instead': 858,
#  'loudly': 859,
#  'chasing': 860,
#  'complied': 861,
#  'rib': 862,
#  'intervened': 863,
#  'station': 864,
#  'card': 865,
#  'rock': 866,
#  'created': 867,
#  'word': 868,
#  'permission': 869,
#  'transferred': 870,
#  'following': 871,
#  'previously': 872,
#  'full': 873,
#  'abusive': 874,
#  'living': 875,
#  'scream': 876,
#  'paper': 877,
#  'stole': 878,
#  'breaking': 879,
#  'danger': 880,
#  '14': 881,
#  'noted': 882,
#  '37': 883,
#  'attempting': 884,
#  'bus': 885,
#  'classmate': 886,
#  'directs': 887,
#  'injured': 888,
#  'fight': 889,
#  'verified': 890,
#  'story': 891,
#  '38': 892,
#  'nasal': 893,
#  'congestion': 894,
#  'isolate': 895,
#  'leg': 896,
#  'passing': 897,
#  '25pm': 898,
#  'lower': 899,
#  'diagnosis': 900,
#  'colleague': 901,
#  'addressed': 902,
#  'swearing': 903,
#  'alpha': 904,
#  'fallen': 905,
#  'table': 906,
#  'close': 907,
#  'seize': 908,
#  'august': 909,
#  'housing': 910,
#  'assault': 911,
#  'investigative': 912,
#  'investigation': 913,
#  '19345882': 914,
#  '407': 915,
#  'action': 916,
#  'picked': 917,
#  'mat': 918,
#  'hold': 919,
#  'remain': 920,
#  'putting': 921,
#  'extremely': 922,
#  'hunched': 923,
#  'weak': 924,
#  'inhaler': 925,
#  'waited': 926,
#  'seemed': 927,
#  'long': 928,
#  'quick': 929,
#  'moaning': 930,
#  'soon': 931,
#  '35': 932,
#  'chocking': 933,
#  'planned': 934,
#  'distressed': 935,
#  'voicemail': 936,
#  'activated': 937,
#  'fact': 938,
#  'hung': 939,
#  'enough': 940,
#  'evaluated': 941,
#  'communicate': 942,
#  'permitted': 943,
#  'abuse': 944,
#  'nervous': 945,
#  'alert': 946,
#  'applied': 947,
#  'drug': 948,
#  'parking': 949,
#  'deal': 950,
#  'presumptive': 951,
#  'muscle': 952,
#  'ache': 953,
#  'headache': 954,
#  'maple': 955,
#  'coughing': 956,
#  'change': 957,
#  'someone31': 958,
#  'onsite': 959,
#  'treatment': 960,
#  'delusional': 961,
#  'incoherent': 962,
#  'gotten': 963,
#  'already': 964,
#  'anyone': 965,
#  '304': 966,
#  'paranoia': 967,
#  'removal': 968,
#  'yes': 969,
#  '05am': 970,
#  '604': 971,
#  'become': 972,
#  'disturbance': 973,
#  'heavily': 974,
#  'sugar': 975,
#  '17pm': 976,
#  'suspected': 977,
#  'lead': 978,
#  'resistant': 979,
#  '722': 980,
#  'present': 981,
#  'monitored': 982,
#  'driver': 983,
#  'abdominal': 984,
#  '54': 985,
#  'wearing': 986,
#  'losing': 987,
#  'refusal': 988,
#  'unsuccessful': 989,
#  'remained': 990,
#  'conducted': 991,
#  'buzz': 992,
#  'deny': 993,
#  'guy': 994,
#  'someoneff': 995,
#  'someonee': 996,
#  'someoneh': 997,
#  '25am': 998,
#  'urgent': 999,
#  'afterwards': 1000,
#  ...}

# %% [markdown]
# Here we use basic model in tensorflow sequential. the neutral network architecture consist:
# 1. embedding layer. this layer should always be our default unless we train and import our own specilized embedding matrix.
# 2. max pooling here is to retain the max activation value. polling is to pick max value on each output dims of the array. at the same time since we are using binary loss so we need make sure last layer will out out 1D
# 3. Dense layer with 24 output diemnsions and contain most popular activiation function so far relu
# 4. output layer. since it is binary classfier so we use sigmoid activation function with 1 output

# %%
model = Sequential([Embedding(input_dim = unique_words, output_dim=128,input_length=max_len),
                    GlobalMaxPooling1D(),
                   Dense(128,activation="relu"),
                   Dropout(0.2),
                   Dense(128,activation="relu"),
                   Dropout(0.5),
                   Dense(1,activation='sigmoid')]
                  )
model.compile(loss="binary_crossentropy",optimizer = 'adam',metrics = ["accuracy","AUC"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 102, 128)          257280
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 290,433
# Trainable params: 290,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
output = "model_output/dense"
modelcheck = ModelCheckpoint(filepath = output + "weight.{epoch:2d}.hdf5")
if not os.path.exists(output):
    os.makedirs(output)

# %% [markdown]
# we set to train 30 epochs to run and find best weights for the model

# %%
num_epochs = 40
history = model.fit(padded_train,Y_train,
                    batch_size = 128,
                    epochs = num_epochs,
                    validation_data = (padded_test,Y_test),
                    verbose = 2,
                    callbacks = [modelcheck])
# Out:
# Train on 268 samples, validate on 67 samples
# Epoch 1/40
# 268/268 - 0s - loss: 0.0042 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.8955 - val_AUC: 0.9232
# Epoch 2/40
# 268/268 - 0s - loss: 0.0020 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4659 - val_accuracy: 0.8955 - val_AUC: 0.9228
# Epoch 3/40
# 268/268 - 0s - loss: 0.0075 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4705 - val_accuracy: 0.8955 - val_AUC: 0.9241
# Epoch 4/40
# 268/268 - 0s - loss: 0.0026 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4779 - val_accuracy: 0.8806 - val_AUC: 0.9250
# Epoch 5/40
# 268/268 - 0s - loss: 0.0070 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4891 - val_accuracy: 0.8507 - val_AUC: 0.9152
# Epoch 6/40
# 268/268 - 0s - loss: 0.0079 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4958 - val_accuracy: 0.8507 - val_AUC: 0.9152
# Epoch 7/40
# 268/268 - 0s - loss: 0.0093 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4819 - val_accuracy: 0.8806 - val_AUC: 0.9143
# Epoch 8/40
# 268/268 - 0s - loss: 0.0029 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.8955 - val_AUC: 0.9330
# Epoch 9/40
# 268/268 - 0s - loss: 0.0091 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4920 - val_accuracy: 0.8657 - val_AUC: 0.9219
# Epoch 10/40
# 268/268 - 0s - loss: 0.0061 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.8657 - val_AUC: 0.9228
# Epoch 11/40
# 268/268 - 0s - loss: 0.0127 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.8806 - val_AUC: 0.9304
# Epoch 12/40
# 268/268 - 0s - loss: 0.0095 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4712 - val_accuracy: 0.8806 - val_AUC: 0.9304
# Epoch 13/40
# 268/268 - 0s - loss: 0.0073 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.8955 - val_AUC: 0.9219
# Epoch 14/40
# 268/268 - 0s - loss: 0.0100 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4591 - val_accuracy: 0.8955 - val_AUC: 0.9228
# Epoch 15/40
# 268/268 - 0s - loss: 0.0047 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.4708 - val_accuracy: 0.8806 - val_AUC: 0.9241
# Epoch 16/40
# 268/268 - 0s - loss: 0.0063 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4884 - val_accuracy: 0.8507 - val_AUC: 0.9134
# Epoch 17/40
# 268/268 - 0s - loss: 0.0094 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4924 - val_accuracy: 0.8507 - val_AUC: 0.9134
# Epoch 18/40
# 268/268 - 0s - loss: 0.0074 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4835 - val_accuracy: 0.8657 - val_AUC: 0.9143
# Epoch 19/40
# 268/268 - 0s - loss: 0.0044 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4745 - val_accuracy: 0.8657 - val_AUC: 0.9134
# Epoch 20/40
# 268/268 - 0s - loss: 0.0018 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4710 - val_accuracy: 0.8806 - val_AUC: 0.9241
# Epoch 21/40
# 268/268 - 0s - loss: 0.0045 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.9104 - val_AUC: 0.9223
# Epoch 22/40
# 268/268 - 0s - loss: 0.0188 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4644 - val_accuracy: 0.8955 - val_AUC: 0.9232
# Epoch 23/40
# 268/268 - 0s - loss: 0.0032 - accuracy: 1.0000 - AUC: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.8955 - val_AUC: 0.9232
# Epoch 24/40
# 268/268 - 0s - loss: 0.0064 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.8955 - val_AUC: 0.9232
# Epoch 25/40
# 268/268 - 0s - loss: 0.0135 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.5178 - val_accuracy: 0.8358 - val_AUC: 0.9156
# Epoch 26/40
# 268/268 - 0s - loss: 0.0122 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5623 - val_accuracy: 0.8209 - val_AUC: 0.9161
# Epoch 27/40
# 268/268 - 0s - loss: 0.0082 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5883 - val_accuracy: 0.8060 - val_AUC: 0.9161
# Epoch 28/40
# 268/268 - 0s - loss: 0.0171 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.5937 - val_accuracy: 0.8060 - val_AUC: 0.9161
# Epoch 29/40
# 268/268 - 0s - loss: 0.0159 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5238 - val_accuracy: 0.8358 - val_AUC: 0.9152
# Epoch 30/40
# 268/268 - 0s - loss: 0.0093 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4654 - val_accuracy: 0.8955 - val_AUC: 0.9317
# Epoch 31/40
# 268/268 - 0s - loss: 0.0061 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.8657 - val_AUC: 0.9246
# Epoch 32/40
# 268/268 - 0s - loss: 0.0096 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5756 - val_accuracy: 0.8358 - val_AUC: 0.9259
# Epoch 33/40
# 268/268 - 0s - loss: 0.0144 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.6000 - val_accuracy: 0.8209 - val_AUC: 0.9263
# Epoch 34/40
# 268/268 - 0s - loss: 0.0193 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5856 - val_accuracy: 0.8209 - val_AUC: 0.9254
# Epoch 35/40
# 268/268 - 0s - loss: 0.0045 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.8358 - val_AUC: 0.9259
# Epoch 36/40
# 268/268 - 0s - loss: 0.0167 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.5121 - val_accuracy: 0.8507 - val_AUC: 0.9254
# Epoch 37/40
# 268/268 - 0s - loss: 0.0101 - accuracy: 0.9963 - AUC: 0.9999 - val_loss: 0.4550 - val_accuracy: 0.8955 - val_AUC: 0.9312
# Epoch 38/40
# 268/268 - 0s - loss: 0.0143 - accuracy: 0.9925 - AUC: 0.9999 - val_loss: 0.4519 - val_accuracy: 0.8806 - val_AUC: 0.9232
# Epoch 39/40
# 268/268 - 0s - loss: 0.0045 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8060 - val_AUC: 0.9205
# Epoch 40/40
# 268/268 - 0s - loss: 0.0076 - accuracy: 0.9963 - AUC: 1.0000 - val_loss: 0.6269 - val_accuracy: 0.7910 - val_AUC: 0.9223

# %%
model.load_weights("denseweight.22.hdf5")
Y_hat = model.predict_proba(padded_test)
plt.hist(Y_hat)
_= plt.axvline(x=0.5,color = "blue")
plt.show()

# %%
pct_auc = roc_auc_score(Y_test,Y_hat) * 100.0
pct_auc
# Out:
# 92.85714285714286

# %%
float_y_hat = []
for y in Y_hat:
    float_y_hat.append(y[0])
        
ydf =pd.DataFrame(list(zip(float_y_hat,Y_test)),columns=['y_hat','y'])
word_index = tokenizer.word_index
word_index = {k:(v-1) for k,v in word_index.items()}

index_word ={v:k for k,v in word_index.items()}

print(ydf[(ydf.y == 1) & (ydf.y_hat < 0.5)].head(10))
words = ' '.join(index_word[id] for id in padded_test[2])
words
# Out:
#        y_hat  y
# 2   0.002820  1
# 30  0.008968  1
# 59  0.217623  1
# 'included and her and staff leave writer someone her and staff someone on she answering i someone this separated checked he will face answering whilst called wa separated appointment so staff someone she way the yelling someone and police the and for supervisor if to contacted she groaning someone on wa again answering and and provided on someone to wa hospital want writer at went attended someone on and visible to writer at is someone disclosed wa again answering called a separated <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov>'

# %% [markdown]
# examine the sample sentences for test cases
